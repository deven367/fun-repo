# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # lovely-tensors
# > this notebook tries to explore the `lovely-tensors` package

# %%
#| default_exp lovely

# %%
# !pip show lovely-tensors
# Out:
# Name: lovely-tensors
# Version: 0.1.14
# Summary: ❤️ Lovely Tensors
# Home-page: https://github.com/xl0/lovely-tensors
# Author: Alexey Zaytsev
# Author-email: alexey.zaytsev@gmail.com
# License: MIT License
# Location: /home/deven/mambaforge/envs/pth/lib/python3.10/site-packages
# Requires: fastcore, ipython, lovely-numpy, matplotlib, numpy, pillow, torch
# Required-by:

# %%
#|exports
import lovely_tensors as lt
import torch

# %%
#|exports
lt.monkey_patch()

# %%
#|exports
x = torch.randn((3, 100, 100))

# %%
#|exports
x
# Out:
# tensor[3, 100, 100] n=30000 x∈[-4.301, 4.810] μ=0.000 σ=0.996

# %%
#|exports
x.plt.fig

# %%
#|hide
lt.monkey_patch??

# %%
#|exports
x.chans
